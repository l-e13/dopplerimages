# %%
# !pip install pytesseract
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (11.1.0)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.13

# %%
# 🔗 STEP 1: Mount Google Drive
from google.colab import drive
import os
import cv2
import numpy as np
import pytesseract
import csv

drive.mount('/content/drive')

# 📁 STEP 2: Set your image folder path (update if needed!)
image_folder = "/content/drive/My Drive/4th Year/DS 4002/Project 3/Doppler_Images"
output_csv = "/content/drive/My Drive/4th Year/DS 4002/Project 3/ocr_results.csv"
# Out:
# Mounted at /content/drive

# %%
# 🧠 STEP 3: Check if folder exists
if not os.path.exists(image_folder):
    print("🚫 Folder not found. Double-check the path!")
else:
    print("✅ Folder found! Starting OCR...\n")
# Out:
# ✅ Folder found! Starting OCR...

# %%
# 🧬 STEP 4: Run OCR on each image + save results
ocr_config = r'--psm 6 -c tessedit_char_whitelist=0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ/+-μ%.'

with open(output_csv, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Filename', 'DetectedText', 'X', 'Y'])

    for filename in sorted(os.listdir(image_folder)):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            filepath = os.path.join(image_folder, filename)
            print(f"\n📄 Processing: {filename}")

            image = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
            if image is None:
                print(f"❌ Could not read: {filename}")
                continue

            h, w = image.shape
            crop_width = int(w * 0.1)
            scale_bar = image[:, w - crop_width:]

            eq = cv2.equalizeHist(scale_bar)
            _, thresh = cv2.threshold(eq, 160, 255, cv2.THRESH_BINARY)
            inverted = cv2.bitwise_not(thresh)

            data = pytesseract.image_to_data(inverted, config=ocr_config, output_type=pytesseract.Output.DICT)

            results = []
            for i in range(len(data['text'])):
                text = data['text'][i].strip()
                if text:
                    x, y, bw, bh = data['left'][i], data['top'][i], data['width'][i], data['height'][i]
                    cx, cy = x + bw // 2, y + bh // 2
                    full_x = cx + (w - crop_width)
                    results.append((text, full_x, cy))
                    writer.writerow([filename, text, full_x, cy])
                    print(f"  → '{text}' at (x={full_x}, y={cy})")

print("\n✅ Done! Results saved to:", output_csv)
# Out:
# 📄 Processing: 1.jpeg
#   → 'i' at (x=1343, y=11)
#   → 'a' at (x=1410, y=466)
#   → 'ec-2022920AM' at (x=1412, y=556)
#
# 📄 Processing: 10.png
#   → '100' at (x=1007, y=116)
#   → 'cmis' at (x=1013, y=196)
#   → '.' at (x=978, y=253)
#   → '-100' at (x=1010, y=271)
#   → '--200' at (x=998, y=335)
#   → '300' at (x=1010, y=409)
#   → 'stoom' at (x=993, y=490)
#
# 📄 Processing: 11.png
#   → 'mis' at (x=1001, y=109)
#   → '-1.0' at (x=1001, y=178)
#   → '-2.0' at (x=1001, y=248)
#   → '-3.0' at (x=1001, y=317)
#   → '4.0' at (x=1001, y=385)
#   → 'Spin' at (x=1000, y=466)
#
# 📄 Processing: 12.png
#   → '100' at (x=999, y=112)
#   → 'ems' at (x=1002, y=189)
#   → '--100' at (x=1002, y=249)
#   → '200' at (x=1011, y=302)
#   → '300' at (x=1011, y=365)
#   → '400' at (x=1007, y=426)
#   → 'sobom' at (x=991, y=489)
#
# 📄 Processing: 13.png
#   → '-100' at (x=1018, y=121)
#   → '-cm/s' at (x=1025, y=198)
#   → '--100' at (x=1021, y=275)
#   → '--200' at (x=1021, y=351)
#   → '--300' at (x=1021, y=429)
#   → '4bpm' at (x=1018, y=487)
#
# 📄 Processing: 14.jpeg
#   → '.' at (x=987, y=92)
#   → '100' at (x=1016, y=110)
#   → 'i' at (x=1003, y=190)
#   → 'aA' at (x=998, y=248)
#   → '00' at (x=1029, y=264)
#   → '200' at (x=1019, y=328)
#   → '300' at (x=1019, y=402)
#   → '67bpm' at (x=1003, y=470)
#
# 📄 Processing: 15.jpeg
#   → '-' at (x=965, y=47)
#   → '.-' at (x=978, y=63)
#   → '-100' at (x=1003, y=98)
#   → 'cmis' at (x=1017, y=170)
#   → '.' at (x=970, y=200)
#   → '-' at (x=993, y=222)
#   → 'ao' at (x=1024, y=235)
#   → '200' at (x=1013, y=294)
#   → '-300' at (x=1006, y=361)
#   → '7eephP' at (x=1002, y=450)
#
# 📄 Processing: 16.png
#   → 'aE' at (x=1020, y=19)
#   → 'cms' at (x=1021, y=40)
#   → 'i...' at (x=978, y=102)
#   → 'Ps' at (x=980, y=178)
#   → '--200' at (x=991, y=277)
#   → '--300' at (x=991, y=354)
#   → '--400' at (x=991, y=432)
#   → '97bpm' at (x=983, y=464)
#
# 📄 Processing: 17.png
#   → 'Mc' at (x=990, y=109)
#   → '400' at (x=1010, y=178)
#   → '200' at (x=1012, y=254)
#   → '300' at (x=1007, y=329)
#   → '400' at (x=1012, y=406)
#   → '87bpm' at (x=995, y=474)
#
# 📄 Processing: 18.png
#   → 'Ho' at (x=986, y=103)
#   → '--100' at (x=1005, y=188)
#   → '--200' at (x=1005, y=264)
#   → '--300' at (x=1005, y=342)
#   → '--400' at (x=1005, y=419)
#   → '86bpm' at (x=996, y=472)
#
# 📄 Processing: 19.png
#   → 'mis' at (x=1320, y=129)
#   → '0' at (x=1324, y=190)
#   → 'vom' at (x=1312, y=266)
#   → 'vam' at (x=1308, y=343)
#   → 'ata' at (x=1315, y=420)
#   → 'dabom' at (x=1292, y=465)
#
# 📄 Processing: 2.png
#   → 'a' at (x=1425, y=445)
#   → 'lec-2022917AM' at (x=1426, y=535)
#
# 📄 Processing: 20.png
#   → 'a' at (x=1251, y=45)
#   → 'ih' at (x=1226, y=78)
#   → 'x' at (x=1268, y=103)
#   → '-' at (x=1290, y=82)
#   → '--100' at (x=1308, y=196)
#   → '--200' at (x=1308, y=272)
#   → '--300' at (x=1308, y=349)
#   → '--400' at (x=1308, y=426)
#   → 'debpm' at (x=1300, y=456)
#
# 📄 Processing: 21.png
#   → '100' at (x=1321, y=107)
#   → 'A.' at (x=1281, y=174)
#   → '00' at (x=1329, y=245)
#   → 'on' at (x=1321, y=321)
#   → '00' at (x=1328, y=398)
#   → 'toe' at (x=1242, y=488)
#   → 'a' at (x=1301, y=479)
#
# 📄 Processing: 22.png
#   → 'a' at (x=1264, y=41)
#   → 'I' at (x=1240, y=57)
#   → '-100' at (x=1323, y=65)
#   → '1' at (x=1279, y=80)
#   → 'cms' at (x=1333, y=142)
#   → 'a' at (x=1266, y=187)
#   → 'We' at (x=1226, y=205)
#   → 'PYtvoo' at (x=1285, y=222)
#   → 'Tt' at (x=1240, y=238)
#   → 'we' at (x=1240, y=274)
#   → '--200' at (x=1325, y=295)
#   → '--300' at (x=1325, y=372)
#   → 'dgbem' at (x=1311, y=455)
#
# 📄 Processing: 23.png
#   → '-cmis' at (x=1297, y=78)
#   → '--100' at (x=1294, y=155)
#   → '.' at (x=1276, y=194)
#   → 'f' at (x=1193, y=218)
#   → '--200' at (x=1294, y=231)
#   → '1.' at (x=1194, y=250)
#   → '--300' at (x=1294, y=308)
#   → '--400' at (x=1294, y=384)
#   → 'S3bom' at (x=1274, y=465)
#
# 📄 Processing: 24.png
#   → '-' at (x=1311, y=80)
#   → '.' at (x=1295, y=213)
#   → '--100' at (x=1313, y=250)
#   → 'ana' at (x=1311, y=312)
#   → 'saa' at (x=1313, y=388)
#   → 'toe' at (x=1234, y=452)
#   → 'dobom' at (x=1288, y=454)
#
# 📄 Processing: 25.png
#   → '.' at (x=1241, y=85)
#   → '-100' at (x=1327, y=82)
#   → 'Adar' at (x=1257, y=109)
#   → 'mis' at (x=1337, y=159)
#   → 'Le' at (x=1297, y=195)
#   → '1' at (x=1295, y=202)
#   → 'Hy' at (x=1272, y=229)
#   → '100' at (x=1338, y=236)
#   → 'Rr' at (x=1268, y=247)
#   → 'a' at (x=1277, y=278)
#   → 'IN' at (x=1242, y=294)
#   → 'i' at (x=1245, y=312)
#   → '--200' at (x=1329, y=312)
#   → '.' at (x=1241, y=341)
#   → '-300' at (x=1329, y=389)
#   → 'b2bpm' at (x=1321, y=471)
#
# 📄 Processing: 26.png
#   → '1H' at (x=1265, y=69)
#   → '-100' at (x=1311, y=74)
#   → 'ij' at (x=1246, y=93)
#   → 'cmis' at (x=1321, y=151)
#   → 'ay' at (x=1241, y=206)
#   → 'v--t00' at (x=1291, y=231)
#   → '--200' at (x=1313, y=306)
#   → '--300' at (x=1313, y=382)
#   → 'dopo' at (x=1299, y=438)
#
# 📄 Processing: 27.png
#   → '100' at (x=1009, y=83)
#   → 'Bs' at (x=1002, y=169)
#   → '100' at (x=1018, y=235)
#   → '200' at (x=1016, y=311)
#   → '300' at (x=1013, y=388)
#   → '62bpm' at (x=1002, y=456)
#
# 📄 Processing: 28.png
#   → '-100' at (x=1316, y=101)
#   → 'ba' at (x=1247, y=148)
#   → 'Lcmis' at (x=1320, y=175)
#   → '.' at (x=1299, y=219)
#   → '-100' at (x=1318, y=255)
#   → '.' at (x=1299, y=295)
#   → '-200' at (x=1318, y=331)
#   → '-300' at (x=1318, y=409)
#   → 'Rabon' at (x=1298, y=464)
#
# 📄 Processing: 29.png
#   → 'AN' at (x=1249, y=66)
#   → 'olde' at (x=1268, y=135)
#   → 'a' at (x=1275, y=170)
#   → '--100' at (x=1313, y=247)
#   → '200' at (x=1313, y=324)
#   → '300' at (x=1313, y=401)
#   → 'Mbpm' at (x=1307, y=483)
#
# 📄 Processing: 3.png
#   → 'c' at (x=1259, y=559)
#   → '06-Jan-2023' at (x=1210, y=649)
#
# 📄 Processing: 30.png
#   → 'Ne' at (x=1258, y=48)
#   → '-100' at (x=1313, y=100)
#   → 'emis' at (x=1323, y=186)
#   → 'ee' at (x=1287, y=259)
#   → 'A-100' at (x=1303, y=271)
#   → 'M' at (x=1289, y=286)
#   → '--200' at (x=1315, y=359)
#   → '--300' at (x=1315, y=445)
#   → 'tdSbpm' at (x=1297, y=473)
#
# 📄 Processing: 31.jpeg
#   → 'vibe' at (x=1248, y=62)
#   → 'cm/s' at (x=1317, y=115)
#   → 'H' at (x=1286, y=164)
#   → '--100' at (x=1309, y=192)
#   → 're' at (x=1215, y=221)
#   → 'vl' at (x=1215, y=245)
#   → 'J' at (x=1211, y=274)
#   → '--200' at (x=1309, y=270)
#   → 'i' at (x=1208, y=301)
#   → '.' at (x=1291, y=308)
#   → 'iP' at (x=1213, y=325)
#   → '--300' at (x=1309, y=345)
#   → '--400' at (x=1309, y=422)
#   → '+t65bom' at (x=1277, y=451)
#
# 📄 Processing: 32.png
#   → 'di' at (x=1242, y=67)
#   → '-emis' at (x=1320, y=119)
#   → '--100' at (x=1317, y=196)
#   → '.' at (x=1299, y=235)
#   → '--200' at (x=1317, y=272)
#   → '--300' at (x=1317, y=349)
#   → '--400' at (x=1317, y=426)
#   → 'Sbpm' at (x=1300, y=457)
#
# 📄 Processing: 33.png
#   → '.' at (x=1222, y=54)
#   → 'bits' at (x=1282, y=121)
#   → 'Pa' at (x=1254, y=147)
#   → '--100' at (x=1315, y=206)
#   → '--200' at (x=1315, y=282)
#   → '--300' at (x=1315, y=359)
#   → '--400' at (x=1315, y=435)
#   → 'Sopp' at (x=1302, y=466)
#
# 📄 Processing: 34.jpeg
#   → 'aRytiigir' at (x=1263, y=47)
#   → 'SVilirt400' at (x=1290, y=73)
#   → 'emis' at (x=1325, y=154)
#   → 'pay' at (x=1289, y=203)
#   → 'wth' at (x=1264, y=219)
#   → 'yubfia-100' at (x=1284, y=231)
#   → 'Mere' at (x=1256, y=249)
#   → 'os' at (x=1267, y=277)
#   → 'worhg0g' at (x=1290, y=304)
#   → 'si' at (x=1232, y=333)
#   → 'Va-300' at (x=1284, y=381)
#   → 'vil' at (x=1239, y=422)
#   → 'i' at (x=1292, y=425)
#   → 'dshom' at (x=1303, y=441)
#
# 📄 Processing: 35.png
#   → '99' at (x=1320, y=74)
#   → '--100' at (x=1317, y=238)
#   → '0' at (x=1329, y=298)
#   → '0' at (x=1324, y=375)
#   → 'nos' at (x=1238, y=465)
#
# 📄 Processing: 36.png
#   → '-100' at (x=1312, y=92)
#   → 'i' at (x=1229, y=145)
#   → '-' at (x=1295, y=133)
#   → 'j' at (x=1229, y=186)
#   → '-omis' at (x=1317, y=169)
#   → '--100' at (x=1314, y=246)
#   → '--200' at (x=1314, y=322)
#   → '--300' at (x=1314, y=399)
#   → '87bom' at (x=1294, y=455)
#
# 📄 Processing: 37.png
#   → 'a' at (x=1230, y=34)
#   → '.' at (x=1255, y=54)
#   → '-ftt00' at (x=1275, y=77)
#   → 'Wy' at (x=1257, y=101)
#   → '-cmis' at (x=1322, y=149)
#   → 'F' at (x=1227, y=194)
#   → 'i' at (x=1229, y=229)
#   → '-100' at (x=1320, y=226)
#   → '.' at (x=1300, y=266)
#   → 'A' at (x=1223, y=274)
#   → '--200' at (x=1319, y=302)
#   → '-300' at (x=1319, y=379)
#   → 'Sbobem' at (x=1273, y=460)
#
# 📄 Processing: 38.png
#   → '-100' at (x=1308, y=89)
#   → 'Bit' at (x=1218, y=125)
#   → '-' at (x=1292, y=129)
#   → 'emis' at (x=1318, y=166)
#   → 'i' at (x=1242, y=223)
#   → '/' at (x=1235, y=241)
#   → '--100' at (x=1310, y=243)
#   → 'i' at (x=1224, y=266)
#   → '.' at (x=1292, y=283)
#   → '+200' at (x=1310, y=320)
#   → '--300' at (x=1310, y=397)
#   → 'Sthom' at (x=1298, y=453)
#
# 📄 Processing: 39.png
#   → '-100' at (x=1321, y=90)
#   → 'it' at (x=1228, y=158)
#   → 'cms' at (x=1331, y=167)
#   → '.' at (x=1304, y=207)
#   → '--100' at (x=1323, y=244)
#   → '--200' at (x=1323, y=320)
#   → '--300' at (x=1323, y=398)
#   → 'Soom' at (x=1316, y=454)
#
# 📄 Processing: 4.jpeg
#   → '-' at (x=982, y=108)
#   → '100' at (x=1015, y=117)
#   → 'fens' at (x=1009, y=191)
#   → 'aA' at (x=997, y=256)
#   → '00' at (x=1028, y=271)
#   → '200' at (x=1018, y=335)
#   → '300' at (x=1016, y=411)
#   → 'oop' at (x=994, y=490)
#
# 📄 Processing: 40.png
#   → '100' at (x=1012, y=87)
#   → 'cm/s' at (x=1019, y=164)
#   → '-100' at (x=1015, y=241)
#   → '-200' at (x=1015, y=318)
#   → '-300' at (x=1015, y=395)
#   → 'bpm' at (x=1010, y=453)
#
# 📄 Processing: 5.jpeg
#   → 'a' at (x=987, y=214)
#   → '00' at (x=1018, y=229)
#   → '200' at (x=1008, y=293)
#   → '300' at (x=1006, y=369)
#   → '400' at (x=1006, y=446)
#   → '76bpm' at (x=993, y=491)
#
# 📄 Processing: 6.jpeg
#   → 'emis' at (x=1004, y=144)
#   → '00' at (x=1023, y=233)
#   → '200' at (x=1007, y=297)
#   → '300' at (x=1013, y=371)
#   → '400' at (x=1013, y=448)
#   → '4bpm' at (x=1003, y=495)
#
# 📄 Processing: 7.jpeg
#   → '400' at (x=980, y=53)
#   → 'Vt' at (x=954, y=79)
#   → 'fen' at (x=978, y=128)
#   → 'te' at (x=957, y=168)
#   → 'n-400' at (x=987, y=194)
#   → '1' at (x=957, y=221)
#   → '-200' at (x=993, y=267)
#   → 'i' at (x=946, y=305)
#   → 'nL' at (x=960, y=295)
#   → '..300' at (x=985, y=331)
#   → 'a' at (x=957, y=356)
#   → '--400' at (x=993, y=405)
#   → '55ppm' at (x=982, y=438)
#
# 📄 Processing: 8.jpeg
#   → 'j--' at (x=1013, y=112)
#   → 'he' at (x=987, y=160)
#   → '--100' at (x=1023, y=194)
#   → 'hy' at (x=983, y=213)
#   → '1-200' at (x=1018, y=281)
#   → 'Nhl' at (x=983, y=305)
#   → 'yf' at (x=992, y=348)
#   → 'goo' at (x=1032, y=367)
#   → '4' at (x=983, y=386)
#   → 'iv' at (x=993, y=416)
#   → '1-400' at (x=1013, y=449)
#   → '51bpm' at (x=1016, y=472)
#
# 📄 Processing: 9.png
#   → '.' at (x=977, y=71)
#   → '100' at (x=1009, y=80)
#   → 'fens' at (x=999, y=161)
#   → '--100' at (x=1005, y=235)
#   → '200' at (x=1006, y=299)
#   → '300' at (x=1007, y=373)
#   → 'soon' at (x=995, y=454)
#
# ✅ Done! Results saved to: /content/drive/My Drive/4th Year/DS 4002/Project 3/ocr_results.csv
